# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.uniform(-4,4,500)

# %%
y=x+np.random.standard_normal(500)+2.5

# %%
len(y)
# Out:
# 500

# %%
min(y)
# Out:
# -3.7254339719942706

# %%
max(y)
# Out:
# 8.583496361567093

# %%
plt.plot(x,y,"o")

# %%
def cost(X,Y,theta):
    J=np.dot((np.dot(X,theta)-Y).T,(np.dot(X,theta)-Y))/(2*len(Y))
    return J

# %%
alpha=0.1 # specifiying the learning rate
theta=np.array([[0,0]]).T

# %%
import matplotlib.pyplot as plt
x = np.random.uniform(-4,4,500)       
y = x + np.random.standard_normal(500)+2.5
plt.plot(x, y, 'o')
plt.show()
def cost(X, Y, theta):
    J=np.dot((np.dot(X,theta) - Y).T,(np.dot(X,theta) - Y))/(2*len(Y))
    return J
alpha = 0.1 # Specify the learning rate
theta =  np.array([[0,0]]).T # Initial values of theta
X = np.c_[np.ones(500),x]
Y = np.c_[y]
X_1=np.c_[x].T
num_iters = 1000
cost_history=[]
theta_history=[]
for i in range(num_iters):
    a=np.sum(theta[0]- alpha * (1/len(Y)) * np.sum((np.dot(X,theta)- Y)))
    b=np.sum(theta[1] - alpha * (1/len(Y)) * np.sum(np.dot(X_1,(np.dot(X,theta)-Y))))
    theta= np.array([[a],[b]])
cost_history.append(cost(X,Y,theta))
theta_history.append(theta)
print(the)
# Out:
# [[2.56621886]
#  [1.01244387]]

# %%
import matplotlib.pyplot as plt
x = np.random.uniform(-4,4,500)       
y = x + np.random.standard_normal(500)+2.5
plt.plot(x, y, 'o')
plt.show()

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x[0]
# Out:
# 0.2060820338070899

# %%
def cost(X, Y, theta):
    J=np.dot((np.dot(X,theta) - Y).T,(np.dot(X,theta) - Y))/(2*len(Y))
    return J

# %%
x = np.random.uniform(0,1,500)       
y = x + np.random.standard_normal(500)+2.5
alpha = 0.1 # Specify the learning rate
theta =  np.array([[0,0]]).T # Initial values of theta
X = np.c_[np.ones(500),x]
Y = np.c_[y]
X_1=np.c_[x].T
num_iters = 10
cost_history=[]
theta_history=[]
for i in range(num_iters):
    a=np.sum(theta[0]- alpha * (1/len(Y)) * np.sum((np.dot(X,theta)- Y)))
    b=np.sum(theta[1] - alpha * (1/len(Y)) * np.sum(np.dot(X_1,(np.dot(X,theta)-Y))))
    theta= np.array([[a],[b]])
cost_history.append(cost(X,Y,theta))
theta_history.append(theta)

# %%
cost_history
# Out:
# [array([[0.72899289]])]

# %%
theta_history
# Out:
# [array([[1.71524487],
#         [0.885945  ]])]

# %%
import pandas as pd
air=pd.read_csv(r"C:\ksr\data science\DS_batch1\datasets\AirPassengers.csv")

# %%
air.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score Holiday_week  \
# 0         1       37824            517356                4.00000           NO
# 1         2       43936            646086                2.67466           NO
# 2         3       42896            638330                3.29473           NO
# 3         4       35792            506492                3.85684           NO
# 4         5       38624            609658                3.90757           NO
#
#   Delayed_Cancelled_flight_ind  Inter_metro_flight_ratio Bad_Weather_Ind  \
# 0                           NO                      0.70             YES
# 1                          YES                      0.80             YES
# 2                           NO                      0.90              NO
# 3                           NO                      0.40              NO
# 4                           NO                      0.87              NO
#
#   Technical_issues_ind
# 0                  YES
# ...

# %%
x=np.array(air["Promotion_Budget"])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
y=np.array(air["Passengers"])

# %%
type(y)
# Out:
# numpy.ndarray

# %%
alpha = 0.1 # Specify the learning rate
theta =  np.array([[0,0]]).T # Initial values of theta
X = np.c_[np.ones(len(x)),x]
Y = np.c_[y]
X_1=np.c_[x].T
num_iters = 10
cost_history=[]
theta_history=[]
for i in range(num_iters):
    a=np.sum(theta[0]- alpha * (1/len(Y)) * np.sum((np.dot(X,theta)- Y)))
    b=np.sum(theta[1] - alpha * (1/len(Y)) * np.sum(np.dot(X_1,(np.dot(X,theta)-Y))))
    theta= np.array([[a],[b]])
cost_history.append(cost(X,Y,theta))
theta_history.append(theta)
print(theta)
print(cost_history)
# Out:
# [[-1.64323727e+099]
#  [-1.09127562e+105]]
# [array([[2.47312737e+221]])]

# %%
cost_history
# Out:
# [array([[2.47312737e+221]])]

# %%
theta_history
# Out:
# [array([[-1.64323727e+099],
#         [-1.09127562e+105]])]

# %%
x=np.array(air["Promotion_Budget"])
y=np.array(air["Passengers"])
plt.plot(x,y,"o")
alpha = 0.1 # Specify the learning rate
theta =  np.array([[0,0]]).T # Initial values of theta
X = np.c_[np.ones(len(x)),x]
Y = np.c_[y]
X_1=np.c_[x].T
num_iters = 10
cost_history=[]
theta_history=[]
for i in range(num_iters):
    a=np.sum(theta[0]- alpha * (1/len(Y)) * np.sum((np.dot(X,theta)- Y)))
    b=np.sum(theta[1] - alpha * (1/len(Y)) * np.sum(np.dot(X_1,(np.dot(X,theta)-Y))))
    theta= np.array([[a],[b]])
cost_history.append(cost(X,Y,theta))
theta_history.append(theta)
print(cost_history)
print(theta)
# Out:
# [array([[2.47312737e+221]])]
# [[-1.64323727e+099]
#  [-1.09127562e+105]]

# %%
air.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score Holiday_week  \
# 0         1       37824            517356                4.00000           NO
# 1         2       43936            646086                2.67466           NO
# 2         3       42896            638330                3.29473           NO
# 3         4       35792            506492                3.85684           NO
# 4         5       38624            609658                3.90757           NO
#
#   Delayed_Cancelled_flight_ind  Inter_metro_flight_ratio Bad_Weather_Ind  \
# 0                           NO                      0.70             YES
# 1                          YES                      0.80             YES
# 2                           NO                      0.90              NO
# 3                           NO                      0.40              NO
# 4                           NO                      0.87              NO
#
#   Technical_issues_ind
# 0                  YES
# ...

# %%
import statsmodels.formula.api as sm
model=sm.ols(formula="Passengers~Promotion_Budget",data=air).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Passengers   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     1084.
# Date:                Sun, 10 May 2020   Prob (F-statistic):           1.66e-47
# Time:                        08:29:42   Log-Likelihood:                -751.34
# No. Observations:                  80   AIC:                             1507.
# Df Residuals:                      78   BIC:                             1511.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
pred=model.predict()

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(air["Passengers"],pred)
# Out:
# 8415770.663981918

# %%
air1=air[["Passengers","Promotion_Budget"]]

# %%
air1.head()
# Out:
#    Passengers  Promotion_Budget
# 0       37824            517356
# 1       43936            646086
# 2       42896            638330
# 3       35792            506492
# 4       38624            609658

# %%
# applying the min max scalar function
from sklearn.preprocessing import MinMaxScaler
mn=MinMaxScaler()
air2=pd.DataFrame(mn.fit_transform(air1),columns=air1.columns)
air2.head()
# Out:
#    Passengers  Promotion_Budget
# 0    0.173698          0.204257
# 1    0.290055          0.377614
# 2    0.270256          0.367169
# 3    0.135014          0.189627
# 4    0.188928          0.328557

# %%
air2["Passengers"].min()
# Out:
# 0.0

# %%
air2["Passengers"].max()
# Out:
# 1.0

# %%
x=np.array(air2["Promotion_Budget"])
y=np.array(air2["Passengers"])
plt.plot(x,y,"o")
alpha = 0.1 # Specify the learning rate
theta =  np.array([[0,0]]).T # Initial values of theta
X = np.c_[np.ones(len(x)),x]
Y = np.c_[y]
X_1=np.c_[x].T
num_iters = 10
cost_history=[]
theta_history=[]
for i in range(num_iters):
    a=np.sum(theta[0]- alpha * (1/len(Y)) * np.sum((np.dot(X,theta)- Y)))
    b=np.sum(theta[1] - alpha * (1/len(Y)) * np.sum(np.dot(X_1,(np.dot(X,theta)-Y))))
    theta= np.array([[a],[b]])
cost_history.append(cost(X,Y,theta))
theta_history.append(theta)
print(cost_history)
print(theta)
# Out:
# [array([[0.02196108]])]
# [[0.18449179]
#  [0.10526773]]

# %%
import statsmodels.formula.api as sm
model=sm.ols(formula="Passengers~Promotion_Budget",data=air2).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             Passengers   R-squared:                       0.933
# Model:                            OLS   Adj. R-squared:                  0.932
# Method:                 Least Squares   F-statistic:                     1084.
# Date:                Sun, 10 May 2020   Prob (F-statistic):           1.66e-47
# Time:                        08:37:40   Log-Likelihood:                 118.19
# No. Observations:                  80   AIC:                            -232.4
# Df Residuals:                      78   BIC:                            -227.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
pred=model.predict()

# %%
mean_squared_error(air2["Passengers"],pred)
# Out:
# 0.0030500865372497265

# %%
x=np.array(air2["Promotion_Budget"])
y=np.array(air2["Passengers"])
plt.plot(x,y,"o")
alpha = 0.1 # Specify the learning rate
theta =  np.array([[0,1]]).T # Initial values of theta
X = np.c_[np.ones(len(x)),x]
Y = np.c_[y]
X_1=np.c_[x].T
num_iters = 100
cost_history=[]
theta_history=[]
for i in range(num_iters):
    a=np.sum(theta[0]- alpha * (1/len(Y)) * np.sum((np.dot(X,theta)- Y)))
    b=np.sum(theta[1] - alpha * (1/len(Y)) * np.sum(np.dot(X_1,(np.dot(X,theta)-Y))))
    theta= np.array([[a],[b]])
cost_history.append(cost(X,Y,theta))
theta_history.append(theta)
print(cost_history)
print(theta)
# Out:
# [array([[0.00152512]])]
# [[-0.03903455]
#  [ 0.9847866 ]]

# %%
air2["pred_gra"]=air2["Promotion_Budget"]* 0.9847866-0.03903455

# %%
model.params
# Out:
# Intercept          -0.038356
# Promotion_Budget    0.982922
# dtype: float64

# %%
air2["pred_ols"]=air2["Promotion_Budget"]* 0.982922-0.038356

# %%
plt.plot(air2["Promotion_Budget"],air2["Passengers"],"o")
plt.plot(air2["Promotion_Budget"],air2["pred_gra"],"r")
plt.plot(air2["Promotion_Budget"],air2["pred_ols"],"b")

# %%
air2.head()
# Out:
#    Passengers  Promotion_Budget      pred  pred_gra  pred_ols
# 0    0.173698          0.204257  0.162115  0.162115  0.162413
# 1    0.290055          0.377614  0.332834  0.332834  0.332809
# 2    0.270256          0.367169  0.322548  0.322548  0.322542
# 3    0.135014          0.189627  0.147707  0.147707  0.148032
# 4    0.188928          0.328557  0.284524  0.284524  0.284590
