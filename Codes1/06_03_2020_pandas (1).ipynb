# %%
import numpy as np
import pandas as pd

# %%
abc=pd.Series(["ind","aus","nz","sa","ban","eng"])

# %%
type(abc)
# Out:
# pandas.core.series.Series

# %%
abc.shape
# Out:
# (6,)

# %%
abc
# Out:
# 0    ind
# 1    aus
# 2     nz
# 3     sa
# 4    ban
# 5    eng
# dtype: object

# %%
abc1=pd.Series([100,200,300,400,500])
abc1
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64

# %%
abc1=pd.Series([100,200,300,400,500,"india"])
abc1
# Out:
# 0      100
# 1      200
# 2      300
# 3      400
# 4      500
# 5    india
# dtype: object

# %%
quantity=[20,50,60,70]

# %%
abc2=pd.Series(quantity)
abc2
# Out:
# 0    20
# 1    50
# 2    60
# 3    70
# dtype: int64

# %%
abc2.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
abc2.idxmax
# Out:
# <bound method Series.idxmax of 0    20
# 1    50
# 2    60
# 3    70
# dtype: int64>

# %%
fruits=["apple","oranges","pears","cherries"]

# %%
abc2=pd.Series(quantity,index=fruits)

# %%
abc2
# Out:
# apple       20
# oranges     50
# pears       60
# cherries    70
# dtype: int64

# %%
years=range(2014,2018)

# %%
list(years)
# Out:
# [2014, 2015, 2016, 2017]

# %%
com1=pd.Series([1000,2000,3000,4000],index=years)
com2=pd.Series([5000,6000,7000,8000],index=years)
com3=pd.Series([9000,10000,11000,12000],index=years)

# %%
pd.concat([com1,com2,com3])
# Out:
# 2014     1000
# 2015     2000
# 2016     3000
# 2017     4000
# 2014     5000
# 2015     6000
# 2016     7000
# 2017     8000
# 2014     9000
# 2015    10000
# 2016    11000
# 2017    12000
# dtype: int64

# %%
pd.concat([com1,com2,com3],axis=0)
# Out:
# 2014     1000
# 2015     2000
# 2016     3000
# 2017     4000
# 2014     5000
# 2015     6000
# 2016     7000
# 2017     8000
# 2014     9000
# 2015    10000
# 2016    11000
# 2017    12000
# dtype: int64

# %%
pd.concat([com1,com2,com3],axis=1)
# Out:
#          0     1      2
# 2014  1000  5000   9000
# 2015  2000  6000  10000
# 2016  3000  7000  11000
# 2017  4000  8000  12000

# %%
com1=pd.Series([1000,2000,None,None],index=years)
com2=pd.Series([5000,6000,7000,8000],index=years)
com3=pd.Series([9000,10000,11000,12000],index=years)

# %%
com1
# Out:
# 2014    1000.0
# 2015    2000.0
# 2016       NaN
# 2017       NaN
# dtype: float64

# %%
pd.concat([com1,com2,com3],axis=0)
# Out:
# 2014     1000.0
# 2015     2000.0
# 2016        NaN
# 2017        NaN
# 2014     5000.0
# 2015     6000.0
# 2016     7000.0
# 2017     8000.0
# 2014     9000.0
# 2015    10000.0
# 2016    11000.0
# 2017    12000.0
# dtype: float64

# %%
dict1={"Name":"Tara","age":30}

# %%
type(dict1)
# Out:
# dict

# %%
pd.DataFrame(dict1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-61e7200a0cc7> in <module>
# ----> 1 pd.DataFrame(dict1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     409             )
#     410         elif isinstance(data, dict):
# --> 411             mgr = init_dict(data, index, columns, dtype=dtype)
#     412         elif isinstance(data, ma.MaskedArray):
#     413             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     255             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     256         ]
# --> 257     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     258
#     259
#
# ...

# %%
dict1={"Name":["Tara"],"age":[30]}

# %%
pd.DataFrame(dict1)
# Out:
#    Name  age
# 0  Tara   30

# %%
dict1={"Name":["KSR","Data Science","NLP","ML","DL"],"exp":[8,8,5,8,4]}

# %%
type(dict1)
# Out:
# dict

# %%
pd.DataFrame(dict1)
# Out:
#            Name  exp
# 0           KSR    8
# 1  Data Science    8
# 2           NLP    5
# 3            ML    8
# 4            DL    4

# %%
dict1={"Name":["KSR","Data Science","NLP","ML","DL"],"exp":[8,8,5,4,8]}

# %%
type(dict1)
# Out:
# dict

# %%
pd.DataFrame(dict1)
# Out:
#            Name  exp
# 0           KSR    8
# 1  Data Science    8
# 2           NLP    5
# 3            ML    4
# 4            DL    8

# %%
ordrinal=["zero","one","two","three","four"]

# %%
abc2=pd.DataFrame(dict1,index=ordrinal)

# %%
abc2
# Out:
#                Name  exp
# zero            KSR    8
# one    Data Science    8
# two             NLP    5
# three            ML    4
# four             DL    8

# %%
abc3=abc2.rename(columns={"Name":"Subject","exp":"experience"})

# %%
abc3
# Out:
#             Subject  experience
# zero            KSR           8
# one    Data Science           8
# two             NLP           5
# three            ML           4
# four             DL           8

# %%
abc3=pd.DataFrame(dict1,columns=["exp","Name"])

# %%
abc3
# Out:
#    exp          Name
# 0    8           KSR
# 1    8  Data Science
# 2    5           NLP
# 3    4            ML
# 4    8            DL

# %%
abc3.reindex(index=[0,2,1,4,3],columns=["Name","exp"])
# Out:
#            Name  exp
# 0           KSR    8
# 2           NLP    5
# 1  Data Science    8
# 4            DL    8
# 3            ML    4

# %%
abc3.columns
# Out:
# Index(['exp', 'Name'], dtype='object')

# %%
list(abc3.columns)
# Out:
# ['exp', 'Name']

# %%
abc3.exp
# Out:
# 0    8
# 1    8
# 2    5
# 3    4
# 4    8
# Name: exp, dtype: int64

# %%
abc3["exp"]
# Out:
# 0    8
# 1    8
# 2    5
# 3    4
# 4    8
# Name: exp, dtype: int64

# %%
abc3.ndim
# Out:
# 2

# %%
abc3["exp"].sum()
# Out:
# 33

# %%
abc3["exp"].cumsum()
# Out:
# 0     8
# 1    16
# 2    21
# 3    25
# 4    33
# Name: exp, dtype: int64

# %%
abc3["loc"]="bangalore"

# %%
abc3["area"]=20000

# %%
abc3
# Out:
#    exp          Name        loc   area
# 0    8           KSR  bangalore  20000
# 1    8  Data Science  bangalore  20000
# 2    5           NLP  bangalore  20000
# 3    4            ML  bangalore  20000
# 4    8            DL  bangalore  20000

# %%
print(abc3)
# Out:
#    exp          Name        loc   area
# 0    8           KSR  bangalore  20000
# 1    8  Data Science  bangalore  20000
# 2    5           NLP  bangalore  20000
# 3    4            ML  bangalore  20000
# 4    8            DL  bangalore  20000

# %%
abc3["area1"]=np.where(abc3["exp"]==8,40000,90000)

# %%
abc3
# Out:
#    exp          Name        loc   area  area1
# 0    8           KSR  bangalore  20000  40000
# 1    8  Data Science  bangalore  20000  40000
# 2    5           NLP  bangalore  20000  90000
# 3    4            ML  bangalore  20000  90000
# 4    8            DL  bangalore  20000  40000

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Koti\\Documents\\Data_Science\\DS_FEB_2020\\codes'

# %%
path=r"C:\ksr\data science\DS_batch1\datasets"

# %%
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\ksr\\data science\\DS_batch1\\datasets'

# %%
air=pd.read_csv(r"C:\ksr\data science\DS_batch1\datasets\AirPassengers.csv")

# %%
air=pd.read_csv("C:/ksr/data science/DS_batch1/datasets/AirPassengers.csv")

# %%
air=pd.read_csv("C:\\ksr\\data science\\DS_batch1\\datasets\\AirPassengers.csv")

# %%
os.getcwd()
# Out:
# 'C:\\ksr\\data science\\DS_batch1\\datasets'

# %%
air=pd.read_csv("AirPassengers.csv")

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer:Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
air=pd.read_csv("AirPassengers.csv")

# %%
air.shape
# Out:
# (80, 9)

# %%
air=pd.read_csv("AirPassengers.csv",nrows=10)

# %%
air.shape
# Out:
# (10, 9)

# %%
air=pd.read_csv("AirPassengers.csv",nrows=len(list(range(20,40,2))))

# %%
air.shape
# Out:
# (10, 9)

# %%
range(20,40)
# Out:
# range(20, 40)

# %%
len(list(range(20,40,2)))
# Out:
# 10

# %%
air=pd.read_csv("AirPassengers.csv",nrows=10)

# %%
air.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score Holiday_week  \
# 0         1       37824            517356                4.00000           NO
# 1         2       43936            646086                2.67466           NO
# 2         3       42896            638330                3.29473           NO
# 3         4       35792            506492                3.85684           NO
# 4         5       38624            609658                3.90757           NO
#
#   Delayed_Cancelled_flight_ind  Inter_metro_flight_ratio Bad_Weather_Ind  \
# 0                           NO                      0.70             YES
# 1                          YES                      0.80             YES
# 2                           NO                      0.90              NO
# 3                           NO                      0.40              NO
# 4                           NO                      0.87              NO
#
#   Technical_issues_ind
# 0                  YES
# ...

# %%
air=pd.read_csv("AirPassengers.csv",nrows=10)
air
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score Holiday_week  \
# 0         1       37824            517356                4.00000           NO
# 1         2       43936            646086                2.67466           NO
# 2         3       42896            638330                3.29473           NO
# 3         4       35792            506492                3.85684           NO
# 4         5       38624            609658                3.90757           NO
# 5         6       35744            476084                3.83710           NO
# 6         7       40752            635978                3.60259           NO
# 7         8       34592            495152                3.60086           NO
# 8         9       35136            429800                3.62776           NO
# 9        10       43328            613326                2.98305           NO
#
#   Delayed_Cancelled_flight_ind  Inter_metro_flight_ratio Bad_Weather_Ind  \
# ...

# %%
air=pd.read_csv("AirPassengers.csv",nrows=10)
col=list(air.columns)

# %%
air=pd.read_csv("AirPassengers.csv",skiprows=10,header=None,names=col)
air
# Out:
#     Week_num  Passengers  Promotion_Budget  Service_Quality_Score  \
# 0         10       43328            613326                2.98305
# 1         11       34960            492758                3.60089
# 2         12       44464            600726                2.56064
# 3         13       36464            456960                3.89655
# 4         14       44464            586096                2.47713
# ..       ...         ...               ...                    ...
# 66        76       66934            927696                1.07138
# 67        77       81228           1108254                0.85536
# 68        78       43288            638162                3.08191
# 69        79       43834            636636                2.75382
# 70        80       40852            575008                3.52768
#
#    Holiday_week Delayed_Cancelled_flight_ind  Inter_metro_flight_ratio  \
# 0            NO                           NO                      0.66
# ...

# %%
air=pd.read_csv("AirPassengers.csv",nrows=10,usecols=[1,2])

# %%
air.head()
# Out:
#    Passengers  Promotion_Budget
# 0       37824            517356
# 1       43936            646086
# 2       42896            638330
# 3       35792            506492
# 4       38624            609658

# %%
air=pd.read_csv("AirPassengers.csv",nrows=10,usecols=["Passengers","Promotion_Budget"])

# %%
air.head()
# Out:
#    Passengers  Promotion_Budget
# 0       37824            517356
# 1       43936            646086
# 2       42896            638330
# 3       35792            506492
# 4       38624            609658

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer:Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
prj=pd.read_csv("Project Data_cs0.txt",sep=":")

# %%
prj.head()
# Out:
#   row_type      entry_id type_of_en dr_cr entry_amt    val_dt   post_dt  \
# 0        D  100628001GG1          T     C     50000  28062010  28062010
# 1        D  10062800311D          T     C     25000  28062010  28062010
# 2        D  100628005FZ3          T     C      7500  28062010  28062010
# 3        D  1006280057UX          T     C     15000  28062010  28062010
# 4        D  100628004U9B          T     C    100000  28062010  28062010
#
#   prod_code                             pkup_loc  \
# 0       CLE    Siliguri ( WEST BENGAL ) BR# 0184
# 1       CLE        Tirur (MALAPPURAM) KER 676101
# 2       CLE                               Raipur
# 3       CLE                    Guna -473001 - MP
# 4       CLE  TRIVANDRUM ( MICR CHQ ONLY ) KERALA
#
#                           pkup_pt  ...   inst_dt          drawer_nam  \
# 0                        Siliguri  ...   3052010       1600010003490
# 1                           TIRUR  ...  17062010       ABDUL LATHEEF
# ...

# %%
prj.shape
# Out:
# (5081, 30)

# %%
col_acq = ['LoanID','Channel','SellerName','OrInterestRate','OrUnpaidPrinc','OrLoanTerm',
         'OrDate','FirstPayment','OrLTV','OrCLTV','NumBorrow','DTIRat','CreditScore',
        'FTHomeBuyer','LoanPurpose','PropertyType','NumUnits','OccStatus','PropertyState',
        'Zip','MortInsPerc','ProductType','CoCreditScore','MortInsType','RelMortInd']

# %%
acq=pd.read_csv(r"C:\Users\Koti\Downloads\Acquisition_2007Q4.txt",sep="|",header=None,names=col_acq)

# %%
acq.head()
# Out:
#          LoanID Channel             SellerName  OrInterestRate  OrUnpaidPrinc  \
# 0  100002296854       C  BANK OF AMERICA, N.A.           6.625         343000
# 1  100006876815       C  BANK OF AMERICA, N.A.           6.250         400000
# 2  100008184591       B                  OTHER           6.625          81000
# 3  100008870761       B           AMTRUST BANK           6.500         119000
# 4  100013284158       B  BANK OF AMERICA, N.A.           6.625         205000
#
#    OrLoanTerm   OrDate FirstPayment  OrLTV  OrCLTV  ...  PropertyType  \
# 0         360  10/2007      12/2007     86    86.0  ...            PU
# 1         360  10/2007      12/2007     62    62.0  ...            SF
# 2         360  11/2007      01/2008     64    82.0  ...            SF
# 3         360  11/2007      01/2008     71    71.0  ...            CO
# 4         360  10/2007      12/2007     27    27.0  ...            SF
#
#    NumUnits  OccStatus PropertyState  Zip MortInsPerc  ProductType  \
# ...

# %%
abc=pd.DataFrame({"Name":["Tara"],"age":[40]})

# %%
abc
# Out:
#    Name  age
# 0  Tara   40

# %%
abc.rename(columns={"Name":"person","age":"exp"})
# Out:
#   person  exp
# 0   Tara   40

# %%
abc
# Out:
#    Name  age
# 0  Tara   40

# %%
abc1=pd.DataFrame({"Name":["koti"],"age":[29]})

# %%
abc1
# Out:
#    Name  age
# 0  koti   29

# %%
abc.append(abc1)
# Out:
#    Name  age
# 0  Tara   40
# 0  koti   29

# %%
abc2=abc.append(abc1).reset_index()

# %%
abc2
# Out:
#    index  Name  age
# 0      0  Tara   40
# 1      0  koti   29

# %%
air.head()
# Out:
#    Passengers  Promotion_Budget
# 0       37824            517356
# 1       43936            646086
# 2       42896            638330
# 3       35792            506492
# 4       38624            609658

# %%
air["row_no"]=air.index

# %%
air.head()
# Out:
#    Passengers  Promotion_Budget  row_no
# 0       37824            517356       0
# 1       43936            646086       1
# 2       42896            638330       2
# 3       35792            506492       3
# 4       38624            609658       4

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer:Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
import numpy as np
import pandas as pd

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Koti\\Documents\\Data_Science\\DS_FEB_2020\\codes'

# %%
path=r"C:\ksr\data science\DS_batch1\datasets"

# %%
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\ksr\\data science\\DS_batch1\\datasets'

# %%
gdp=pd.read_csv("GDP.csv",encoding="iso-8859-1")

# %% [markdown]
# # reading the excel file into python

# %%
wb=pd.read_excel("World Bank Indicators.xlsx")

# %%
wb.head()
# Out:
#   Country Name       Date  Transit: Railways, (million passenger-km)  \
# 0  Afghanistan 2000-07-01                                        0.0
# 1  Afghanistan 2001-07-01                                        0.0
# 2  Afghanistan 2002-07-01                                        0.0
# 3  Afghanistan 2003-07-01                                        0.0
# 4  Afghanistan 2004-07-01                                        0.0
#
#    Transit: Passenger cars (per 1,000 people)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Business: Mobile phone subscribers  \
# 0                                 0.0
# 1                                 0.0
# 2                             25000.0
# 3                            200000.0
# 4                            600000.0
#
# ...

# %%
wb=pd.read_excel("World Bank Indicators.xlsx",sheet_name="Regions and subregions")

# %%
wb.head()
# Out:
#    Region        Subregion      Country
# 0    Asia              NaN  Afghanistan
# 1  Europe      Independent      Albania
# 2  Africa  Northern Africa      Algeria
# 3  Europe      Independent      Andorra
# 4  Africa    Middle Africa       Angola

# %%
os.getcwd()
# Out:
# 'C:\\ksr\\data science\\DS_batch1\\datasets'

# %%
os.listdir()
# Out:
# ['2015.csv',
#  '2016.csv',
#  '2017.csv',
#  'Adj_Sample.csv',
#  'AirPassengers',
#  'AirPassengers.csv',
#  'AutoDataset - Copy.csv',
#  'AutoDataset.csv',
#  'bank_market - Copy.csv',
#  'bank_market.csv',
#  'Boston.csv',
#  'breast-cancer-wisconsin.data.txt',
#  'breast_cancer.txt',
#  'burger_data.csv',
#  'ConsPolarity.csv',
#  'creditcard.csv',
#  'customer_life_time.xlsx',
#  'cx_payment_behavior.csv',
#  'decision_trees.xlsx',
#  'diabetes.csv',
#  'Ecom_Cust_Survey.csv',
#  'Emp_Productivity.csv',
#  'fb_posts.csv',
#  'fb_post_comments.csv',
#  'fb_reactions.csv',
#  'fb_user.csv',
#  'fb_user_details.csv',
#  'Fiberbits_excel.xlsx',
#  'Fiberbits_v1.csv',
#  'Final Exam Score.csv',
#  'Final Exam Score_v1.csv',
#  'GDP - Copy.csv',
#  'GDP.csv',
#  'Glassdoor employee reviews.xlsx',
#  'gnp - Copy.sas7bdat',
#  'gnp.sas7bdat',
#  'HR_comma_sep.csv',
#  'Income_data.csv',
#  'Iris.csv',
#  'loan.csv',
#  'MNIST_data',
#  'movie_metadata.csv',
#  'Online Retail.csv',
# ...

# %%
gnp=pd.read_sas("gnp.sas7bdat")
gnp.shape
# Out:
# (126, 6)

# %%
eda=pd.read_html(r"C:\Users\Koti\Downloads\EDA.html")

# %%
eda
# Out:
# [              Unnamed: 0    count        mean        std    min     25%  \
#  0     satisfaction_level  11991.0    0.629658   0.241070   0.09    0.48
#  1        last_evaluation  11991.0    0.716683   0.168343   0.36    0.57
#  2         number_project  11991.0    3.802852   1.163238   2.00    3.00
#  3   average_montly_hours  11991.0  200.473522  48.727813  96.00  157.00
#  4     time_spend_company  11991.0    3.364857   1.330240   2.00    3.00
#  5          Work_accident  11991.0    0.154282   0.361234   0.00    0.00
#  6                   left  11991.0    0.166041   0.372133   0.00    0.00
#  7  promotion_last_5years  11991.0    0.016929   0.129012   0.00    0.00
#
#        50%     75%    max
#  0    0.66    0.82    1.0
#  1    0.72    0.86    1.0
#  2    4.00    5.00    7.0
#  3  200.00  243.00  310.0
#  4    3.00    4.00   10.0
#  5    0.00    0.00    1.0
#  6    0.00    0.00    1.0
#  7    0.00    0.00    1.0  ,      left                  0                  1
# ...

# %%
eda1=pd.read_html(r"C:\Users\Koti\Downloads\02_03_2020_File_handling.html")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-2f9b3a1b0729> in <module>
# ----> 1 eda1=pd.read_html(r"C:\Users\Koti\Downloads\02_03_2020_File_handling.html")
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# ~\Anaconda3\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     886     retained = None
#     887     for flav in flavor:
# --> 888         parser = _parser_dispatch(flav)
#     889         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     890
#
# ...

# %%
stores=pd.read_json("stores.json")

# %%
stores
# Out:
#     Store ID       Banner               Region
# 0      66999      Walmart  Northern California
# 1       4698  Trader Joes  Northern California
# 2      39482      Safeway  Northern California
# 3      34957  Whole Foods  Northern California
# 4      12837      Walmart             New York
# 5       9487  Trader Joes             New York
# 6       2938      Wegmans             New York
# 7      50948  Whole Foods             New York
# 8      40593      Walmart               Kansas
# 9      29384  Trader Joes               Kansas
# 10      3948      Wegmans               Kansas
# 11     39485      Safeway               Kansas
# 12     39287  Whole Foods               Kansas
# 13     50495      Walmart                Texas
# 14     40586  Trader Joes                Texas
# 15     98638      Wegmans                Texas
# 16     29382      Safeway                Texas
# 17     98736  Whole Foods                Texas
# 18      6746       Kroger  Northern California
# ...

# %%
auto=pd.read_csv("AutoDataset.csv")

# %%
auto.shape
# Out:
# (205, 26)

# %%
auto.columns
# Out:
# Index([' symboling', ' normalized-losses', ' make', ' fuel-type',
#        ' aspiration', ' num-of-doors', ' body-style', ' drive-wheels',
#        ' engine-location', ' wheel-base', ' length', ' width', ' height',
#        ' curb-weight', ' engine-type', ' num-of-cylinders', ' engine-size',
#        ' fuel-system', ' bore', ' stroke', ' compression-ratio', ' horsepower',
#        ' peak-rpm', ' city-mpg', ' highway-mpg', ' price'],
#       dtype='object')

# %%
auto1=auto.rename(columns=lambda x:x.strip())

# %%
auto1.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
bank=pd.read_csv("bank_market.csv")

# %% [markdown]
# # Basic quality/sanity check

# %%
bank.shape  # dimensions of a data
# Out:
# (45211, 18)

# %%
bank.shape[0]
# Out:
# 45211

# %%
bank.shape[1]
# Out:
# 18

# %%
bank.columns
# Out:
# Index(['Cust_num', 'age', 'job', 'marital', 'education', 'default', 'balance',
#        'housing', 'loan', 'contact', 'day', 'month', 'duration', 'campaign',
#        'pdays', 'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
set(bank.columns)
# Out:
# {'Cust_num',
#  'age',
#  'balance',
#  'campaign',
#  'contact',
#  'day',
#  'default',
#  'duration',
#  'education',
#  'housing',
#  'job',
#  'loan',
#  'marital',
#  'month',
#  'pdays',
#  'poutcome',
#  'previous',
#  'y'}

# %%
bank.dtypes
# Out:
# Cust_num      int64
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
bank.info() # description about the table
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 18 columns):
# Cust_num     45211 non-null int64
# age          45211 non-null int64
# job          45211 non-null object
# marital      45211 non-null object
# education    45211 non-null object
# default      45211 non-null object
# balance      45211 non-null int64
# housing      45211 non-null object
# loan         45211 non-null object
# contact      45211 non-null object
# day          45211 non-null int64
# month        45211 non-null object
# duration     45211 non-null int64
# campaign     45211 non-null int64
# pdays        45211 non-null int64
# previous     45211 non-null int64
# poutcome     45211 non-null object
# y            45211 non-null object
# dtypes: int64(8), object(10)
# memory usage: 6.2+ MB

# %%
auto.shape
# Out:
# (205, 26)

# %%
auto.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  symboling            205 non-null int64
#  normalized-losses    164 non-null float64
#  make                 205 non-null object
#  fuel-type            205 non-null object
#  aspiration           205 non-null object
#  num-of-doors         203 non-null object
#  body-style           205 non-null object
#  drive-wheels         205 non-null object
#  engine-location      205 non-null object
#  wheel-base           205 non-null float64
#  length               205 non-null float64
#  width                205 non-null float64
#  height               205 non-null float64
#  curb-weight          205 non-null int64
#  engine-type          205 non-null object
#  num-of-cylinders     205 non-null object
#  engine-size          205 non-null int64
#  fuel-system          205 non-null object
#  bore                 201 non-null float64
#  stroke               201 non-null float64
# ...

# %%
auto.isna().sum()
# Out:
#  symboling             0
#  normalized-losses    41
#  make                  0
#  fuel-type             0
#  aspiration            0
#  num-of-doors          2
#  body-style            0
#  drive-wheels          0
#  engine-location       0
#  wheel-base            0
#  length                0
#  width                 0
#  height                0
#  curb-weight           0
#  engine-type           0
#  num-of-cylinders      0
#  engine-size           0
#  fuel-system           0
#  bore                  4
#  stroke                4
#  compression-ratio     0
#  horsepower            2
#  peak-rpm              2
#  city-mpg              0
#  highway-mpg           0
#  price                 0
# dtype: int64

# %%
len(auto)
# Out:
# 205

# %%
auto.shape[0]
# Out:
# 205

# %%
round(auto.isnull().sum()/len(auto)*100,3)
# Out:
#  symboling             0.000
#  normalized-losses    20.000
#  make                  0.000
#  fuel-type             0.000
#  aspiration            0.000
#  num-of-doors          0.976
#  body-style            0.000
#  drive-wheels          0.000
#  engine-location       0.000
#  wheel-base            0.000
#  length                0.000
#  width                 0.000
#  height                0.000
#  curb-weight           0.000
#  engine-type           0.000
#  num-of-cylinders      0.000
#  engine-size           0.000
#  fuel-system           0.000
#  bore                  1.951
#  stroke                1.951
#  compression-ratio     0.000
#  horsepower            0.976
#  peak-rpm              0.976
#  city-mpg              0.000
#  highway-mpg           0.000
#  price                 0.000
# dtype: float64

# %%
def miss_identify(data):
    return(round(data.isna().sum()/len(data)*100,3))

# %%
miss_identify(stores)
# Out:
# Store ID    0.0
# Banner      0.0
# Region      0.0
# dtype: float64

# %%
miss_cal=lambda x:round(x.isnull().sum()/len(x),3)

# %%
miss_cal(stores)
# Out:
# Store ID    0.0
# Banner      0.0
# Region      0.0
# dtype: float64

# %%
bank.head()
# Out:
#    Cust_num  age           job  marital  education default  balance housing  \
# 0         1   58    management  married   tertiary      no     2143     yes
# 1         2   44    technician   single  secondary      no       29     yes
# 2         3   33  entrepreneur  married  secondary      no        2     yes
# 3         4   47   blue-collar  married    unknown      no     1506     yes
# 4         5   33       unknown   single    unknown      no        1      no
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 0   no  unknown    5   may       261         1     -1         0  unknown  no
# 1   no  unknown    5   may       151         1     -1         0  unknown  no
# 2  yes  unknown    5   may        76         1     -1         0  unknown  no
# 3   no  unknown    5   may        92         1     -1         0  unknown  no
# 4   no  unknown    5   may       198         1     -1         0  unknown  no

# %%
bank.head(10)
# Out:
#    Cust_num  age           job   marital  education default  balance housing  \
# 0         1   58    management   married   tertiary      no     2143     yes
# 1         2   44    technician    single  secondary      no       29     yes
# 2         3   33  entrepreneur   married  secondary      no        2     yes
# 3         4   47   blue-collar   married    unknown      no     1506     yes
# 4         5   33       unknown    single    unknown      no        1      no
# 5         6   35    management   married   tertiary      no      231     yes
# 6         7   28    management    single   tertiary      no      447     yes
# 7         8   42  entrepreneur  divorced   tertiary     yes        2     yes
# 8         9   58       retired   married    primary      no      121     yes
# 9        10   43    technician    single  secondary      no      593     yes
#
#   loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
bank.tail()
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 45206      no   no   cellular   17   nov       977         3     -1         0
# 45207      no   no   cellular   17   nov       456         2     -1         0
# 45208      no   no   cellular   17   nov      1127         5    184         3
# 45209      no   no  telephone   17   nov       508         4     -1         0
# 45210      no   no   cellular   17   nov       361         2    188        11
#
#       poutcome    y
# 45206  unknown  yes
# ...

# %%
bank.tail(10)
# Out:
#        Cust_num  age           job   marital  education default  balance  \
# 45201     45202   53    management   married   tertiary      no      583
# 45202     45203   34        admin.    single  secondary      no      557
# 45203     45204   23       student    single   tertiary      no      113
# 45204     45205   73       retired   married  secondary      no     2850
# 45205     45206   25    technician    single  secondary      no      505
# 45206     45207   51    technician   married   tertiary      no      825
# 45207     45208   71       retired  divorced    primary      no     1729
# 45208     45209   72       retired   married  secondary      no     5715
# 45209     45210   57   blue-collar   married  secondary      no      668
# 45210     45211   37  entrepreneur   married  secondary      no     2971
#
#       housing loan    contact  day month  duration  campaign  pdays  previous  \
# 45201      no   no   cellular   17   nov       226         1    184         4
# ...

# %%
bank[100:105]
# Out:
#      Cust_num  age          job  marital  education default  balance housing  \
# 100       101   44  blue-collar  married  secondary      no     -674     yes
# 101       102   53  blue-collar  married    primary      no       90      no
# 102       103   52  blue-collar  married    primary      no      128     yes
# 103       104   59  blue-collar  married    primary      no      179     yes
# 104       105   27   technician   single   tertiary      no        0     yes
#
#     loan  contact  day month  duration  campaign  pdays  previous poutcome   y
# 100   no  unknown    5   may       257         1     -1         0  unknown  no
# 101   no  unknown    5   may       124         1     -1         0  unknown  no
# 102   no  unknown    5   may       229         1     -1         0  unknown  no
# 103   no  unknown    5   may        55         3     -1         0  unknown  no
# 104   no  unknown    5   may       400         1     -1         0  unknown  no
