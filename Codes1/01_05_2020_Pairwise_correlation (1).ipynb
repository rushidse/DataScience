# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
hr=pd.read_csv(r"C:\ksr\data science\DS_batch1\datasets\AirPassengers1.csv")

# %%
hr.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score Holiday_week  \
# 0         1       37824            517356                4.00000           NO
# 1         2       43936            646086                2.67466           NO
# 2         3       42896            638330                3.29473           NO
# 3         4       35792            506492                3.85684           NO
# 4         5       38624            609658                3.90757           NO
#
#   Delayed_Cancelled_flight_ind  Inter_metro_flight_ratio Bad_Weather_Ind  \
# 0                           NO                      0.70             YES
# 1                          YES                      0.80             YES
# 2                           NO                      0.90              NO
# 3                           NO                      0.40              NO
# 4                           NO                      0.87              NO
#
#   Technical_issues_ind
# 0                  YES
# ...

# %%
air1=pd.get_dummies(hr)

# %%
air1.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score  \
# 0         1       37824            517356                4.00000
# 1         2       43936            646086                2.67466
# 2         3       42896            638330                3.29473
# 3         4       35792            506492                3.85684
# 4         5       38624            609658                3.90757
#
#    Inter_metro_flight_ratio  Holiday_week_NO  Holiday_week_YES  \
# 0                      0.70                1                 0
# 1                      0.80                1                 0
# 2                      0.90                1                 0
# 3                      0.40                1                 0
# 4                      0.87                1                 0
#
#    Delayed_Cancelled_flight_ind_NO  Delayed_Cancelled_flight_ind_YES  \
# 0                                1                                 0
# ...

# %%
air1=pd.get_dummies(hr,drop_first=True,dtype="int")

# %%
air1.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score  \
# 0         1       37824            517356                4.00000
# 1         2       43936            646086                2.67466
# 2         3       42896            638330                3.29473
# 3         4       35792            506492                3.85684
# 4         5       38624            609658                3.90757
#
#    Inter_metro_flight_ratio  Holiday_week_YES  \
# 0                      0.70                 0
# 1                      0.80                 0
# 2                      0.90                 0
# 3                      0.40                 0
# 4                      0.87                 0
#
#    Delayed_Cancelled_flight_ind_YES  Bad_Weather_Ind_YES  \
# 0                                 0                    1
# 1                                 1                    1
# 2                                 0                    0
# 3                                 0                    0
# ...

# %%
s=pd.Series(list("parp"))

# %%
s
# Out:
# 0    p
# 1    a
# 2    r
# 3    p
# dtype: object

# %%
pd.get_dummies(s)
# Out:
#    a  p  r
# 0  0  1  0
# 1  1  0  0
# 2  0  0  1
# 3  0  1  0

# %%
s1=["p","q",np.nan]

# %%
pd.get_dummies(s1)
# Out:
#    p  q
# 0  1  0
# 1  0  1
# 2  0  0

# %%
pd.get_dummies(s1,dummy_na=True)
# Out:
#    p  q  NaN
# 0  1  0    0
# 1  0  1    0
# 2  0  0    1

# %%
air1=pd.get_dummies(hr,drop_first=True,dtype="float")

# %%
air1.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score  \
# 0         1       37824            517356                4.00000
# 1         2       43936            646086                2.67466
# 2         3       42896            638330                3.29473
# 3         4       35792            506492                3.85684
# 4         5       38624            609658                3.90757
#
#    Inter_metro_flight_ratio  Holiday_week_YES  \
# 0                      0.70               0.0
# 1                      0.80               0.0
# 2                      0.90               0.0
# 3                      0.40               0.0
# 4                      0.87               0.0
#
#    Delayed_Cancelled_flight_ind_YES  Bad_Weather_Ind_YES  \
# 0                               0.0                  1.0
# 1                               1.0                  1.0
# 2                               0.0                  0.0
# 3                               0.0                  0.0
# ...

# %%
help(pd.get_dummies)
# Out:
# Help on function get_dummies in module pandas.core.reshape.reshape:
#
# get_dummies(data, prefix=None, prefix_sep='_', dummy_na=False, columns=None, sparse=False, drop_first=False, dtype=None) -> 'DataFrame'
#     Convert categorical variable into dummy/indicator variables.
#
#     Parameters
#     ----------
#     data : array-like, Series, or DataFrame
#         Data of which to get dummy indicators.
#     prefix : str, list of str, or dict of str, default None
#         String to append DataFrame column names.
#         Pass a list with length equal to the number of columns
#         when calling get_dummies on a DataFrame. Alternatively, `prefix`
#         can be a dictionary mapping column names to prefixes.
#     prefix_sep : str, default '_'
#         If appending prefix, separator/delimiter to use. Or pass a
#         list or dictionary as with `prefix`.
#     dummy_na : bool, default False
#         Add a column to indicate NaNs, if False NaNs are ignored.
# ...

# %%
air1.head()
# Out:
#    Week_num  Passengers  Promotion_Budget  Service_Quality_Score  \
# 0         1       37824            517356                4.00000
# 1         2       43936            646086                2.67466
# 2         3       42896            638330                3.29473
# 3         4       35792            506492                3.85684
# 4         5       38624            609658                3.90757
#
#    Inter_metro_flight_ratio  Holiday_week_YES  \
# 0                      0.70               0.0
# 1                      0.80               0.0
# 2                      0.90               0.0
# 3                      0.40               0.0
# 4                      0.87               0.0
#
#    Delayed_Cancelled_flight_ind_YES  Bad_Weather_Ind_YES  \
# 0                               0.0                  1.0
# 1                               1.0                  1.0
# 2                               0.0                  0.0
# 3                               0.0                  0.0
# ...

# %%
air1["Passengers"].skew()
# Out:
# 1.314495852821924

# %%
air1.corr()
# Out:
#                                   Week_num  Passengers  Promotion_Budget  \
# Week_num                          1.000000    0.412820          0.392003
# Passengers                        0.412820    1.000000          0.965851
# Promotion_Budget                  0.392003    0.965851          1.000000
# Service_Quality_Score            -0.394892   -0.886530         -0.843382
# Inter_metro_flight_ratio          0.188979    0.491947          0.531449
# Holiday_week_YES                  0.407681    0.821298          0.757834
# Delayed_Cancelled_flight_ind_YES  0.053606    0.116224          0.127543
# Bad_Weather_Ind_YES               0.016239    0.114404          0.119175
# Technical_issues_ind_YES         -0.002168   -0.243588         -0.210171
#
#                                   Service_Quality_Score  \
# Week_num                                      -0.394892
# Passengers                                    -0.886530
# Promotion_Budget                              -0.843382
# ...

# %%
sns.heatmap(air1.corr(),linecolor="blue",linewidths=3,annot=True,fmt=".5g",cmap="Greens",center=None)

# %%
air2=abs(air1.corrwith(air1["Passengers"]))<0.5

# %%
air2[air2==False]
# Out:
# Passengers               False
# Promotion_Budget         False
# Service_Quality_Score    False
# Holiday_week_YES         False
# dtype: bool
